# %%
import utils
import numpy as np
import re
import pandas as pd
import importlib
importlib.reload(utils)

# %%
iteraciones=100
Ts = [10, 100, 1000]
Ps=[1e3]

# %%
iteraciones=100
Ts = [10]
Ps=[1e2, 1e3, 1e6, 1e7]

# %% [markdown]
# ## Generacion

# %%
for T in Ts:
    for P in Ps:
        for k in range(iteraciones):
            victorias=[[np.random.randint(P)*(i!=j)  for i in range(T)] for j in range(T)]
            utils.test_generator(f'random{T}_{P}/{k}', victorias, with_matches=False)

# %% [markdown]
# ## Testeo

# %%
results, reference = utils.results(with_matches=False)
by_T = (lambda results: {(T, P): [result for file,result in results.items() if re.match(f'.*/random{T}_{P}/.*', file)] for T in Ts for P in Ps} )
results = by_T(results)
reference = by_T(reference)
error = {(T, P): [max(abs(((np.array(own)-np.array(ref))/np.array(own)))) for own, ref in zip(results[(T, P)], reference[(T, P)])] for (T, P) in results}
# Out:
# generating ../tests/random10_1000.0/0.out
# generating ../tests/random10_1000.0/0.expected
# generating ../tests/random10_1000.0/1.out
# generating ../tests/random10_1000.0/1.expected
# generating ../tests/random10_1000.0/2.out
# generating ../tests/random10_1000.0/2.expected
# generating ../tests/random10_1000.0/3.out
# generating ../tests/random10_1000.0/3.expected
# generating ../tests/random10_1000.0/4.out
# generating ../tests/random10_1000.0/4.expected
# generating ../tests/random10_1000.0/5.out
# generating ../tests/random10_1000.0/5.expected
# generating ../tests/random10_1000.0/6.out
# generating ../tests/random10_1000.0/6.expected
# generating ../tests/random10_1000.0/7.out
# generating ../tests/random10_1000.0/7.expected
# generating ../tests/random10_1000.0/8.out
# generating ../tests/random10_1000.0/8.expected
# generating ../tests/random10_1000.0/9.out
# generating ../tests/random10_1000.0/9.expected
# generating ../tests/random10_1000.0/10.out
# generating ../tests/random10_1000.0/10.expected
# generating ../tests/random10_1000.0/11.out
# generating ../tests/random10_1000.0/11.expected
# generating ../tests/random10_1000.0/12.out
# generating ../tests/random10_1000.0/12.expected
# generating ../tests/random10_1000.0/13.out
# generating ../tests/random10_1000.0/13.expected
# generating ../tests/random10_1000.0/14.out
# generating ../tests/random10_1000.0/14.expected
# generating ../tests/random10_1000.0/15.out
# generating ../tests/random10_1000.0/15.expected
# generating ../tests/random10_1000.0/16.out
# generating ../tests/random10_1000.0/16.expected
# generating ../tests/random10_1000.0/17.out
# generating ../tests/random10_1000.0/17.expected
# generating ../tests/random10_1000.0/18.out
# generating ../tests/random10_1000.0/18.expected
# generating ../tests/random10_1000.0/19.out
# generating ../tests/random10_1000.0/19.expected
# generating ../tests/random10_1000.0/20.out
# generating ../tests/random10_1000.0/20.expected
# generating ../tests/random10_1000.0/21.out
# generating ../tests/random10_1000.0/21.expected
# generating ../tests/random10_1000.0/22.out
# generating ../tests/random10_1000.0/22.expected
# generating ../tests/random10_1000.0/23.out
# generating ../tests/random10_1000.0/23.expected
# generating ../tests/random10_1000.0/24.out
# generating ../tests/random10_1000.0/24.expected
# generating ../tests/random10_1000.0/25.out
# generating ../tests/random10_1000.0/25.expected
# generating ../tests/random10_1000.0/26.out
# generating ../tests/random10_1000.0/26.expected
# generating ../tests/random10_1000.0/27.out
# generating ../tests/random10_1000.0/27.expected
# generating ../tests/random10_1000.0/28.out
# generating ../tests/random10_1000.0/28.expected
# generating ../tests/random10_1000.0/29.out
# generating ../tests/random10_1000.0/29.expected
# generating ../tests/random10_1000.0/30.out
# generating ../tests/random10_1000.0/30.expected
# generating ../tests/random10_1000.0/31.out
# generating ../tests/random10_1000.0/31.expected
# generating ../tests/random10_1000.0/32.out
# generating ../tests/random10_1000.0/32.expected
# generating ../tests/random10_1000.0/33.out
# generating ../tests/random10_1000.0/33.expected
# generating ../tests/random10_1000.0/34.out
# generating ../tests/random10_1000.0/34.expected
# generating ../tests/random10_1000.0/35.out
# generating ../tests/random10_1000.0/35.expected
# generating ../tests/random10_1000.0/36.out
# generating ../tests/random10_1000.0/36.expected
# generating ../tests/random10_1000.0/37.out
# generating ../tests/random10_1000.0/37.expected
# generating ../tests/random10_1000.0/38.out
# generating ../tests/random10_1000.0/38.expected
# generating ../tests/random10_1000.0/39.out
# generating ../tests/random10_1000.0/39.expected
# generating ../tests/random10_1000.0/40.out
# generating ../tests/random10_1000.0/40.expected
# generating ../tests/random10_1000.0/41.out
# generating ../tests/random10_1000.0/41.expected
# generating ../tests/random10_1000.0/42.out
# generating ../tests/random10_1000.0/42.expected
# generating ../tests/random10_1000.0/43.out
# generating ../tests/random10_1000.0/43.expected
# generating ../tests/random10_1000.0/44.out
# generating ../tests/random10_1000.0/44.expected
# generating ../tests/random10_1000.0/45.out
# generating ../tests/random10_1000.0/45.expected
# generating ../tests/random10_1000.0/46.out
# generating ../tests/random10_1000.0/46.expected
# generating ../tests/random10_1000.0/47.out
# generating ../tests/random10_1000.0/47.expected
# generating ../tests/random10_1000.0/48.out
# generating ../tests/random10_1000.0/48.expected
# generating ../tests/random10_1000.0/49.out
# generating ../tests/random10_1000.0/49.expected
# generating ../tests/random10_1000.0/50.out
# generating ../tests/random10_1000.0/50.expected
# generating ../tests/random10_1000.0/51.out
# generating ../tests/random10_1000.0/51.expected
# generating ../tests/random10_1000.0/52.out
# generating ../tests/random10_1000.0/52.expected
# generating ../tests/random10_1000.0/53.out
# generating ../tests/random10_1000.0/53.expected
# generating ../tests/random10_1000.0/54.out
# generating ../tests/random10_1000.0/54.expected
# generating ../tests/random10_1000.0/55.out
# generating ../tests/random10_1000.0/55.expected
# generating ../tests/random10_1000.0/56.out
# generating ../tests/random10_1000.0/56.expected
# generating ../tests/random10_1000.0/57.out
# generating ../tests/random10_1000.0/57.expected
# generating ../tests/random10_1000.0/58.out
# generating ../tests/random10_1000.0/58.expected
# generating ../tests/random10_1000.0/59.out
# generating ../tests/random10_1000.0/59.expected
# generating ../tests/random10_1000.0/60.out
# generating ../tests/random10_1000.0/60.expected
# generating ../tests/random10_1000.0/61.out
# generating ../tests/random10_1000.0/61.expected
# generating ../tests/random10_1000.0/62.out
# generating ../tests/random10_1000.0/62.expected
# generating ../tests/random10_1000.0/63.out
# generating ../tests/random10_1000.0/63.expected
# generating ../tests/random10_1000.0/64.out
# generating ../tests/random10_1000.0/64.expected
# generating ../tests/random10_1000.0/65.out
# generating ../tests/random10_1000.0/65.expected
# generating ../tests/random10_1000.0/66.out
# generating ../tests/random10_1000.0/66.expected
# generating ../tests/random10_1000.0/67.out
# generating ../tests/random10_1000.0/67.expected
# generating ../tests/random10_1000.0/68.out
# generating ../tests/random10_1000.0/68.expected
# generating ../tests/random10_1000.0/69.out
# generating ../tests/random10_1000.0/69.expected
# generating ../tests/random10_1000.0/70.out
# generating ../tests/random10_1000.0/70.expected
# generating ../tests/random10_1000.0/71.out
# generating ../tests/random10_1000.0/71.expected
# generating ../tests/random10_1000.0/72.out
# generating ../tests/random10_1000.0/72.expected
# generating ../tests/random10_1000.0/73.out
# generating ../tests/random10_1000.0/73.expected
# generating ../tests/random10_1000.0/74.out
# generating ../tests/random10_1000.0/74.expected
# generating ../tests/random10_1000.0/75.out
# generating ../tests/random10_1000.0/75.expected
# generating ../tests/random10_1000.0/76.out
# generating ../tests/random10_1000.0/76.expected
# generating ../tests/random10_1000.0/77.out
# generating ../tests/random10_1000.0/77.expected
# generating ../tests/random10_1000.0/78.out
# generating ../tests/random10_1000.0/78.expected
# generating ../tests/random10_1000.0/79.out
# generating ../tests/random10_1000.0/79.expected
# generating ../tests/random10_1000.0/80.out
# generating ../tests/random10_1000.0/80.expected
# generating ../tests/random10_1000.0/81.out
# generating ../tests/random10_1000.0/81.expected
# generating ../tests/random10_1000.0/82.out
# generating ../tests/random10_1000.0/82.expected
# generating ../tests/random10_1000.0/83.out
# generating ../tests/random10_1000.0/83.expected
# generating ../tests/random10_1000.0/84.out
# generating ../tests/random10_1000.0/84.expected
# generating ../tests/random10_1000.0/85.out
# generating ../tests/random10_1000.0/85.expected
# generating ../tests/random10_1000.0/86.out
# generating ../tests/random10_1000.0/86.expected
# generating ../tests/random10_1000.0/87.out
# generating ../tests/random10_1000.0/87.expected
# generating ../tests/random10_1000.0/88.out
# generating ../tests/random10_1000.0/88.expected
# generating ../tests/random10_1000.0/89.out
# generating ../tests/random10_1000.0/89.expected
# generating ../tests/random10_1000.0/90.out
# generating ../tests/random10_1000.0/90.expected
# generating ../tests/random10_1000.0/91.out
# generating ../tests/random10_1000.0/91.expected
# generating ../tests/random10_1000.0/92.out
# generating ../tests/random10_1000.0/92.expected
# generating ../tests/random10_1000.0/93.out
# generating ../tests/random10_1000.0/93.expected
# generating ../tests/random10_1000.0/94.out
# generating ../tests/random10_1000.0/94.expected
# generating ../tests/random10_1000.0/95.out
# generating ../tests/random10_1000.0/95.expected
# generating ../tests/random10_1000.0/96.out
# generating ../tests/random10_1000.0/96.expected
# generating ../tests/random10_1000.0/97.out
# generating ../tests/random10_1000.0/97.expected
# generating ../tests/random10_1000.0/98.out
# generating ../tests/random10_1000.0/98.expected
# generating ../tests/random10_1000.0/99.out
# generating ../tests/random10_1000.0/99.expected
# generating ../tests/random100_1000.0/0.out
# generating ../tests/random100_1000.0/0.expected
# generating ../tests/random100_1000.0/1.out
# generating ../tests/random100_1000.0/1.expected
# generating ../tests/random100_1000.0/2.out
# generating ../tests/random100_1000.0/2.expected
# generating ../tests/random100_1000.0/3.out
# generating ../tests/random100_1000.0/3.expected
# generating ../tests/random100_1000.0/4.out
# generating ../tests/random100_1000.0/4.expected
# generating ../tests/random100_1000.0/5.out
# generating ../tests/random100_1000.0/5.expected
# generating ../tests/random100_1000.0/6.out
# generating ../tests/random100_1000.0/6.expected
# generating ../tests/random100_1000.0/7.out
# generating ../tests/random100_1000.0/7.expected
# generating ../tests/random100_1000.0/8.out
# generating ../tests/random100_1000.0/8.expected
# generating ../tests/random100_1000.0/9.out
# generating ../tests/random100_1000.0/9.expected
# generating ../tests/random100_1000.0/10.out
# generating ../tests/random100_1000.0/10.expected
# generating ../tests/random100_1000.0/11.out
# generating ../tests/random100_1000.0/11.expected
# generating ../tests/random100_1000.0/12.out
# generating ../tests/random100_1000.0/12.expected
# generating ../tests/random100_1000.0/13.out
# generating ../tests/random100_1000.0/13.expected
# generating ../tests/random100_1000.0/14.out
# generating ../tests/random100_1000.0/14.expected
# generating ../tests/random100_1000.0/15.out
# generating ../tests/random100_1000.0/15.expected
# generating ../tests/random100_1000.0/16.out
# generating ../tests/random100_1000.0/16.expected
# generating ../tests/random100_1000.0/17.out
# generating ../tests/random100_1000.0/17.expected
# generating ../tests/random100_1000.0/18.out
# generating ../tests/random100_1000.0/18.expected
# generating ../tests/random100_1000.0/19.out
# generating ../tests/random100_1000.0/19.expected
# generating ../tests/random100_1000.0/20.out
# generating ../tests/random100_1000.0/20.expected
# generating ../tests/random100_1000.0/21.out
# generating ../tests/random100_1000.0/21.expected
# generating ../tests/random100_1000.0/22.out
# generating ../tests/random100_1000.0/22.expected
# generating ../tests/random100_1000.0/23.out
# generating ../tests/random100_1000.0/23.expected
# generating ../tests/random100_1000.0/24.out
# generating ../tests/random100_1000.0/24.expected
# generating ../tests/random100_1000.0/25.out
# generating ../tests/random100_1000.0/25.expected
# generating ../tests/random100_1000.0/26.out
# generating ../tests/random100_1000.0/26.expected
# generating ../tests/random100_1000.0/27.out
# generating ../tests/random100_1000.0/27.expected
# generating ../tests/random100_1000.0/28.out
# generating ../tests/random100_1000.0/28.expected
# generating ../tests/random100_1000.0/29.out
# generating ../tests/random100_1000.0/29.expected
# generating ../tests/random100_1000.0/30.out
# generating ../tests/random100_1000.0/30.expected
# generating ../tests/random100_1000.0/31.out
# generating ../tests/random100_1000.0/31.expected
# generating ../tests/random100_1000.0/32.out
# generating ../tests/random100_1000.0/32.expected
# generating ../tests/random100_1000.0/33.out
# generating ../tests/random100_1000.0/33.expected
# generating ../tests/random100_1000.0/34.out
# generating ../tests/random100_1000.0/34.expected
# generating ../tests/random100_1000.0/35.out
# generating ../tests/random100_1000.0/35.expected
# generating ../tests/random100_1000.0/36.out
# generating ../tests/random100_1000.0/36.expected
# generating ../tests/random100_1000.0/37.out
# generating ../tests/random100_1000.0/37.expected
# generating ../tests/random100_1000.0/38.out
# generating ../tests/random100_1000.0/38.expected
# generating ../tests/random100_1000.0/39.out
# generating ../tests/random100_1000.0/39.expected
# generating ../tests/random100_1000.0/40.out
# generating ../tests/random100_1000.0/40.expected
# generating ../tests/random100_1000.0/41.out
# generating ../tests/random100_1000.0/41.expected
# generating ../tests/random100_1000.0/42.out
# generating ../tests/random100_1000.0/42.expected
# generating ../tests/random100_1000.0/43.out
# generating ../tests/random100_1000.0/43.expected
# generating ../tests/random100_1000.0/44.out
# generating ../tests/random100_1000.0/44.expected
# generating ../tests/random100_1000.0/45.out
# generating ../tests/random100_1000.0/45.expected
# generating ../tests/random100_1000.0/46.out
# generating ../tests/random100_1000.0/46.expected
# generating ../tests/random100_1000.0/47.out
# generating ../tests/random100_1000.0/47.expected
# generating ../tests/random100_1000.0/48.out
# generating ../tests/random100_1000.0/48.expected
# generating ../tests/random100_1000.0/49.out
# generating ../tests/random100_1000.0/49.expected
# generating ../tests/random100_1000.0/50.out
# generating ../tests/random100_1000.0/50.expected
# generating ../tests/random100_1000.0/51.out
# generating ../tests/random100_1000.0/51.expected
# generating ../tests/random100_1000.0/52.out
# generating ../tests/random100_1000.0/52.expected
# generating ../tests/random100_1000.0/53.out
# generating ../tests/random100_1000.0/53.expected
# generating ../tests/random100_1000.0/54.out
# generating ../tests/random100_1000.0/54.expected
# generating ../tests/random100_1000.0/55.out
# generating ../tests/random100_1000.0/55.expected
# generating ../tests/random100_1000.0/56.out
# generating ../tests/random100_1000.0/56.expected
# generating ../tests/random100_1000.0/57.out
# generating ../tests/random100_1000.0/57.expected
# generating ../tests/random100_1000.0/58.out
# generating ../tests/random100_1000.0/58.expected
# generating ../tests/random100_1000.0/59.out
# generating ../tests/random100_1000.0/59.expected
# generating ../tests/random100_1000.0/60.out
# generating ../tests/random100_1000.0/60.expected
# generating ../tests/random100_1000.0/61.out
# generating ../tests/random100_1000.0/61.expected
# generating ../tests/random100_1000.0/62.out
# generating ../tests/random100_1000.0/62.expected
# generating ../tests/random100_1000.0/63.out
# generating ../tests/random100_1000.0/63.expected
# generating ../tests/random100_1000.0/64.out
# generating ../tests/random100_1000.0/64.expected
# generating ../tests/random100_1000.0/65.out
# generating ../tests/random100_1000.0/65.expected
# generating ../tests/random100_1000.0/66.out
# generating ../tests/random100_1000.0/66.expected
# generating ../tests/random100_1000.0/67.out
# generating ../tests/random100_1000.0/67.expected
# generating ../tests/random100_1000.0/68.out
# generating ../tests/random100_1000.0/68.expected
# generating ../tests/random100_1000.0/69.out
# generating ../tests/random100_1000.0/69.expected
# generating ../tests/random100_1000.0/70.out
# generating ../tests/random100_1000.0/70.expected
# generating ../tests/random100_1000.0/71.out
# generating ../tests/random100_1000.0/71.expected
# generating ../tests/random100_1000.0/72.out
# generating ../tests/random100_1000.0/72.expected
# generating ../tests/random100_1000.0/73.out
# generating ../tests/random100_1000.0/73.expected
# generating ../tests/random100_1000.0/74.out
# generating ../tests/random100_1000.0/74.expected
# generating ../tests/random100_1000.0/75.out
# generating ../tests/random100_1000.0/75.expected
# generating ../tests/random100_1000.0/76.out
# generating ../tests/random100_1000.0/76.expected
# generating ../tests/random100_1000.0/77.out
# generating ../tests/random100_1000.0/77.expected
# generating ../tests/random100_1000.0/78.out
# generating ../tests/random100_1000.0/78.expected
# generating ../tests/random100_1000.0/79.out
# generating ../tests/random100_1000.0/79.expected
# generating ../tests/random100_1000.0/80.out
# generating ../tests/random100_1000.0/80.expected
# generating ../tests/random100_1000.0/81.out
# generating ../tests/random100_1000.0/81.expected
# generating ../tests/random100_1000.0/82.out
# generating ../tests/random100_1000.0/82.expected
# generating ../tests/random100_1000.0/83.out
# generating ../tests/random100_1000.0/83.expected
# generating ../tests/random100_1000.0/84.out
# generating ../tests/random100_1000.0/84.expected
# generating ../tests/random100_1000.0/85.out
# generating ../tests/random100_1000.0/85.expected
# generating ../tests/random100_1000.0/86.out
# generating ../tests/random100_1000.0/86.expected
# generating ../tests/random100_1000.0/87.out
# generating ../tests/random100_1000.0/87.expected
# generating ../tests/random100_1000.0/88.out
# generating ../tests/random100_1000.0/88.expected
# generating ../tests/random100_1000.0/89.out
# generating ../tests/random100_1000.0/89.expected
# generating ../tests/random100_1000.0/90.out
# generating ../tests/random100_1000.0/90.expected
# generating ../tests/random100_1000.0/91.out
# generating ../tests/random100_1000.0/91.expected
# generating ../tests/random100_1000.0/92.out
# generating ../tests/random100_1000.0/92.expected
# generating ../tests/random100_1000.0/93.out
# generating ../tests/random100_1000.0/93.expected
# generating ../tests/random100_1000.0/94.out
# generating ../tests/random100_1000.0/94.expected
# generating ../tests/random100_1000.0/95.out
# generating ../tests/random100_1000.0/95.expected
# generating ../tests/random100_1000.0/96.out
# generating ../tests/random100_1000.0/96.expected
# generating ../tests/random100_1000.0/97.out
# generating ../tests/random100_1000.0/97.expected
# generating ../tests/random100_1000.0/98.out
# generating ../tests/random100_1000.0/98.expected
# generating ../tests/random100_1000.0/99.out
# generating ../tests/random100_1000.0/99.expected
# generating ../tests/random1000_1000.0/0.out
# generating ../tests/random1000_1000.0/0.expected
# generating ../tests/random1000_1000.0/1.out
# generating ../tests/random1000_1000.0/1.expected
# generating ../tests/random1000_1000.0/2.out
# generating ../tests/random1000_1000.0/2.expected
# generating ../tests/random1000_1000.0/3.out
# generating ../tests/random1000_1000.0/3.expected
# generating ../tests/random1000_1000.0/4.out
# generating ../tests/random1000_1000.0/4.expected
# generating ../tests/random1000_1000.0/5.out
# generating ../tests/random1000_1000.0/5.expected
# generating ../tests/random1000_1000.0/6.out
# generating ../tests/random1000_1000.0/6.expected
# generating ../tests/random1000_1000.0/7.out
# generating ../tests/random1000_1000.0/7.expected
# generating ../tests/random1000_1000.0/8.out
# generating ../tests/random1000_1000.0/8.expected
# generating ../tests/random1000_1000.0/9.out
# generating ../tests/random1000_1000.0/9.expected
# generating ../tests/random1000_1000.0/10.out
# generating ../tests/random1000_1000.0/10.expected
# generating ../tests/random1000_1000.0/11.out
# generating ../tests/random1000_1000.0/11.expected
# generating ../tests/random1000_1000.0/12.out
# generating ../tests/random1000_1000.0/12.expected
# generating ../tests/random1000_1000.0/13.out
# generating ../tests/random1000_1000.0/13.expected
# generating ../tests/random1000_1000.0/14.out
# generating ../tests/random1000_1000.0/14.expected
# generating ../tests/random1000_1000.0/15.out
# generating ../tests/random1000_1000.0/15.expected
# generating ../tests/random1000_1000.0/16.out
# generating ../tests/random1000_1000.0/16.expected
# generating ../tests/random1000_1000.0/17.out
# generating ../tests/random1000_1000.0/17.expected
# generating ../tests/random1000_1000.0/18.out
# generating ../tests/random1000_1000.0/18.expected
# generating ../tests/random1000_1000.0/19.out
# generating ../tests/random1000_1000.0/19.expected
# generating ../tests/random1000_1000.0/20.out
# generating ../tests/random1000_1000.0/20.expected
# generating ../tests/random1000_1000.0/21.out
# generating ../tests/random1000_1000.0/21.expected
# generating ../tests/random1000_1000.0/22.out
# generating ../tests/random1000_1000.0/22.expected
# generating ../tests/random1000_1000.0/23.out
# generating ../tests/random1000_1000.0/23.expected
# generating ../tests/random1000_1000.0/24.out
# generating ../tests/random1000_1000.0/24.expected
# generating ../tests/random1000_1000.0/25.out
# generating ../tests/random1000_1000.0/25.expected
# generating ../tests/random1000_1000.0/26.out
# generating ../tests/random1000_1000.0/26.expected
# generating ../tests/random1000_1000.0/27.out
# generating ../tests/random1000_1000.0/27.expected
# generating ../tests/random1000_1000.0/28.out
# generating ../tests/random1000_1000.0/28.expected
# generating ../tests/random1000_1000.0/29.out
# generating ../tests/random1000_1000.0/29.expected
# generating ../tests/random1000_1000.0/30.out
# generating ../tests/random1000_1000.0/30.expected
# generating ../tests/random1000_1000.0/31.out
# generating ../tests/random1000_1000.0/31.expected
# generating ../tests/random1000_1000.0/32.out
# generating ../tests/random1000_1000.0/32.expected
# generating ../tests/random1000_1000.0/33.out
# generating ../tests/random1000_1000.0/33.expected
# generating ../tests/random1000_1000.0/34.out
# generating ../tests/random1000_1000.0/34.expected
# generating ../tests/random1000_1000.0/35.out
# generating ../tests/random1000_1000.0/35.expected
# generating ../tests/random1000_1000.0/36.out
# generating ../tests/random1000_1000.0/36.expected
# generating ../tests/random1000_1000.0/37.out
# generating ../tests/random1000_1000.0/37.expected
# generating ../tests/random1000_1000.0/38.out
# generating ../tests/random1000_1000.0/38.expected
# generating ../tests/random1000_1000.0/39.out
# generating ../tests/random1000_1000.0/39.expected
# generating ../tests/random1000_1000.0/40.out
# generating ../tests/random1000_1000.0/40.expected
# generating ../tests/random1000_1000.0/41.out
# generating ../tests/random1000_1000.0/41.expected
# generating ../tests/random1000_1000.0/42.out
# generating ../tests/random1000_1000.0/42.expected
# generating ../tests/random1000_1000.0/43.out
# generating ../tests/random1000_1000.0/43.expected
# generating ../tests/random1000_1000.0/44.out
# generating ../tests/random1000_1000.0/44.expected
# generating ../tests/random1000_1000.0/45.out
# generating ../tests/random1000_1000.0/45.expected
# generating ../tests/random1000_1000.0/46.out
# generating ../tests/random1000_1000.0/46.expected
# generating ../tests/random1000_1000.0/47.out
# generating ../tests/random1000_1000.0/47.expected
# generating ../tests/random1000_1000.0/48.out
# generating ../tests/random1000_1000.0/48.expected
# generating ../tests/random1000_1000.0/49.out
# generating ../tests/random1000_1000.0/49.expected
# generating ../tests/random1000_1000.0/50.out
# generating ../tests/random1000_1000.0/50.expected
# generating ../tests/random1000_1000.0/51.out
# generating ../tests/random1000_1000.0/51.expected
# generating ../tests/random1000_1000.0/52.out
# generating ../tests/random1000_1000.0/52.expected
# generating ../tests/random1000_1000.0/53.out
# generating ../tests/random1000_1000.0/53.expected
# generating ../tests/random1000_1000.0/54.out
# generating ../tests/random1000_1000.0/54.expected
# generating ../tests/random1000_1000.0/55.out
# generating ../tests/random1000_1000.0/55.expected
# generating ../tests/random1000_1000.0/56.out
# generating ../tests/random1000_1000.0/56.expected
# generating ../tests/random1000_1000.0/57.out
# generating ../tests/random1000_1000.0/57.expected
# generating ../tests/random1000_1000.0/58.out
# generating ../tests/random1000_1000.0/58.expected
# generating ../tests/random1000_1000.0/59.out
# generating ../tests/random1000_1000.0/59.expected
# generating ../tests/random1000_1000.0/60.out
# generating ../tests/random1000_1000.0/60.expected
# generating ../tests/random1000_1000.0/61.out
# generating ../tests/random1000_1000.0/61.expected
# generating ../tests/random1000_1000.0/62.out
# generating ../tests/random1000_1000.0/62.expected
# generating ../tests/random1000_1000.0/63.out
# generating ../tests/random1000_1000.0/63.expected
# generating ../tests/random1000_1000.0/64.out
# generating ../tests/random1000_1000.0/64.expected
# generating ../tests/random1000_1000.0/65.out
# generating ../tests/random1000_1000.0/65.expected
# generating ../tests/random1000_1000.0/66.out
# generating ../tests/random1000_1000.0/66.expected
# generating ../tests/random1000_1000.0/67.out
# generating ../tests/random1000_1000.0/67.expected
# generating ../tests/random1000_1000.0/68.out
# generating ../tests/random1000_1000.0/68.expected
# generating ../tests/random1000_1000.0/69.out
# generating ../tests/random1000_1000.0/69.expected
# generating ../tests/random1000_1000.0/70.out
# generating ../tests/random1000_1000.0/70.expected
# generating ../tests/random1000_1000.0/71.out
# generating ../tests/random1000_1000.0/71.expected
# generating ../tests/random1000_1000.0/72.out
# generating ../tests/random1000_1000.0/72.expected
# generating ../tests/random1000_1000.0/73.out
# generating ../tests/random1000_1000.0/73.expected
# generating ../tests/random1000_1000.0/74.out
# generating ../tests/random1000_1000.0/74.expected
# generating ../tests/random1000_1000.0/75.out
# generating ../tests/random1000_1000.0/75.expected
# generating ../tests/random1000_1000.0/76.out
# generating ../tests/random1000_1000.0/76.expected
# generating ../tests/random1000_1000.0/77.out
# generating ../tests/random1000_1000.0/77.expected
# generating ../tests/random1000_1000.0/78.out
# generating ../tests/random1000_1000.0/78.expected
# generating ../tests/random1000_1000.0/79.out
# generating ../tests/random1000_1000.0/79.expected
# generating ../tests/random1000_1000.0/80.out
# generating ../tests/random1000_1000.0/80.expected
# generating ../tests/random1000_1000.0/81.out
# generating ../tests/random1000_1000.0/81.expected
# generating ../tests/random1000_1000.0/82.out
# generating ../tests/random1000_1000.0/82.expected
# generating ../tests/random1000_1000.0/83.out
# generating ../tests/random1000_1000.0/83.expected
# generating ../tests/random1000_1000.0/84.out
# generating ../tests/random1000_1000.0/84.expected
# generating ../tests/random1000_1000.0/85.out
# generating ../tests/random1000_1000.0/85.expected
# generating ../tests/random1000_1000.0/86.out
# generating ../tests/random1000_1000.0/86.expected
# generating ../tests/random1000_1000.0/87.out
# generating ../tests/random1000_1000.0/87.expected
# generating ../tests/random1000_1000.0/88.out
# generating ../tests/random1000_1000.0/88.expected
# generating ../tests/random1000_1000.0/89.out
# generating ../tests/random1000_1000.0/89.expected
# generating ../tests/random1000_1000.0/90.out
# generating ../tests/random1000_1000.0/90.expected
# generating ../tests/random1000_1000.0/91.out
# generating ../tests/random1000_1000.0/91.expected
# generating ../tests/random1000_1000.0/92.out
# generating ../tests/random1000_1000.0/92.expected
# generating ../tests/random1000_1000.0/93.out
# generating ../tests/random1000_1000.0/93.expected
# generating ../tests/random1000_1000.0/94.out
# generating ../tests/random1000_1000.0/94.expected
# generating ../tests/random1000_1000.0/95.out
# generating ../tests/random1000_1000.0/95.expected
# generating ../tests/random1000_1000.0/96.out
# generating ../tests/random1000_1000.0/96.expected
# generating ../tests/random1000_1000.0/97.out
# generating ../tests/random1000_1000.0/97.expected
# generating ../tests/random1000_1000.0/98.out
# generating ../tests/random1000_1000.0/98.expected
# generating ../tests/random1000_1000.0/99.out
# generating ../tests/random1000_1000.0/99.expected

# %%
edf = pd.DataFrame(error)
edf.columns = edf.columns.rename('T', level=0).rename('Max wins', level=1)
print(edf.describe().to_latex())
# Out:
# \begin{tabular}{lrrr}
# \toprule
# T &          10   &          100  &          1000 \\
# Max wins &        1000.0 &        1000.0 &        1000.0 \\
# \midrule
# count &  1.000000e+02 &  1.000000e+02 &  1.000000e+02 \\
# mean  &  1.006736e-06 &  1.023349e-06 &  1.017009e-06 \\
# std   &  1.669908e-07 &  2.854188e-08 &  7.061043e-09 \\
# min   &  6.710202e-07 &  9.651201e-07 &  1.001799e-06 \\
# 25\%   &  9.030282e-07 &  1.004133e-06 &  1.012125e-06 \\
# 50\%   &  9.769681e-07 &  1.023270e-06 &  1.016109e-06 \\
# 75\%   &  1.112123e-06 &  1.039957e-06 &  1.021296e-06 \\
# max   &  1.579169e-06 &  1.112487e-06 &  1.035555e-06 \\
# \bottomrule
# \end{tabular}
