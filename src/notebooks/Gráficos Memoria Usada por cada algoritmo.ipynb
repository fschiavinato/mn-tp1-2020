# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [5, 3]
plt.rcParams['figure.dpi'] = 200

# %%
y = [93.214708, 69.214692,104.357092,61.166708,61.182708]
x = ['CMM EG','CMM\n Cholesky','CMM Disp.','ELO','WP']
plt.bar(x, y)

plt.xlabel('Algoritmos\n (1000 equipos, 1000 partidos por equipo)')
plt.ylabel('Memoria usada (MB)')
plt.tight_layout()
plt.show()

# %%
y = [48.309952,  24.309952, 43.153984, 16.261952, 16.277952]
x = ['CMM EG','CMM\n Cholesky','CMM Disp.','ELO','WP']
plt.bar(x, y)

plt.xlabel('Algoritmos\n (1000 equipos, 5 partidos por equipo)')
plt.ylabel('Memoria usada (MB)')
plt.tight_layout()
plt.show()
